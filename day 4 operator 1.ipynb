# %%
#bitwise operator
print(11 | 12)
# Out:
# 15

# %%
a=11
b=12
c=bin(a)
print(c)
d=bin(b)
print(d)

#print(a|b)
# Out:
# 0b1011
# 0b1100

# %%
print(6&3)
# Out:
# 2

# %%
a=6
b=3
c=bin(a)
c
d=bin(b)
print(c)
print(d)
print(a&b)
# Out:
# 0b110
# 0b11
# 2

# %%
#bitwise XOR
#both one zero both zero zero

print(6^3)
# Out:
# 5

# %%
a=6
b=3
c=bin(a)
d=bin(b)
print(c)

print(d)
print(a^b)
# Out:
# 0b110
# 0b11
# 5

# %%
print(~3)
# Out:
# -4

# %%
print(3<<2)

#3 = 0000000000000011
#24 = 000000000001100
# Out:
# 12

# %%
print(8>>2)
#8 = 00000000001000
# 2 = 0000000000000010
# Out:
# 2
